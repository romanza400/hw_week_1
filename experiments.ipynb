# %%
import pandas as pd
import numpy as np

import os
from dotenv import load_dotenv

from anthropic import Anthropic

# %%
load_dotenv()
api_key = os.getenv('API_KEY')
model_name = os.getenv('MODEL_NAME')
chat_url = os.getenv('CHAT_URL')

# %%
client = Anthropic(api_key=api_key)

message = client.messages.create(
    model="claude-3-5-sonnet-20241022",  # Актуальная модель
    max_tokens=1024,
    messages=[
        {"role": "user", "content": "Привет, как дела?"}
    ]
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 client = Anthropic()
#       2
# ----> 3 message = client.messages.create(
#       4     model="claude-3-5-sonnet-20241022",  # Актуальная модель
#       5     max_tokens=1024,
#       6     messages=[
#
# File ~/nlp up/hw_week_1/.venv/lib/python3.13/site-packages/anthropic/_utils/_utils.py:294, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     292             msg = f"Missing required argument: {quote(missing[0])}"
#     293     raise TypeError(msg)
# --> 294 return func(*args, **kwargs)
#
# File ~/nlp up/hw_week_1/.venv/lib/python3.13/site-packages/anthropic/resources/messages/messages.py:978, in Messages.create(self, max_tokens, messages, model, cache_control, container, inference_geo, metadata, output_config, service_tier, stop_sequences, stream, system, thinking, tool_choice, tools, user_profile_id, workspace_id, extra_headers, extra_query, extra_body, timeout)
#     963     warnings.warn(
#     964         f"Using Claude with {model} and 'thinking.type=enabled' is deprecated. Use 'thinking.type=adaptive' instead which results in better model performance in our testing: https://platform.claude.com/docs/en/build-with-claude/adaptive-thinking",
#     965         UserWarning,
#     966         stacklevel=3,
#     967     )
#     969 extra_headers = {
#     970     **strip_not_given(
#     971         {
#    (...)    976     **(extra_headers or {}),
#     977 }
# --> 978 return self._post(
#     979     "/v1/messages",
#     980     body=maybe_transform(
#     981         {
#     982             "max_tokens": max_tokens,
#     983             "messages": messages,
#     984             "model": model,
#     985             "cache_control": cache_control,
#     986             "container": container,
#     987             "inference_geo": inference_geo,
#     988             "metadata": metadata,
#     989             "output_config": output_config,
#     990             "service_tier": service_tier,
#     991             "stop_sequences": stop_sequences,
#     992             "stream": stream,
#     993             "system": system,
#     994             "thinking": thinking,
#     995             "tool_choice": tool_choice,
#     996             "tools": tools,
#     997         },
#     998         message_create_params.MessageCreateParamsStreaming
#     999         if stream
#    1000         else message_create_params.MessageCreateParamsNonStreaming,
#    1001     ),
#    1002     options=make_request_options(
#    1003         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1004     ),
#    1005     cast_to=Message,
#    1006     stream=stream or False,
#    1007     stream_cls=Stream[RawMessageStreamEvent],
#    1008 )
#
# File ~/nlp up/hw_week_1/.venv/lib/python3.13/site-packages/anthropic/_base_client.py:1509, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1505     raise TypeError("Passing both `files` and `content` is not supported")
#    1506 opts = FinalRequestOptions.construct(
#    1507     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1508 )
# -> 1509 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/nlp up/hw_week_1/.venv/lib/python3.13/site-packages/anthropic/_base_client.py:1135, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1133 try:
#    1134     if chain is None:
# -> 1135         response, prepared = self._attempt_request(
#    1136             model_copy(input_options), stream=stream, retries_taken=retries_taken
#    1137         )
#    1138         if response.is_success:
#    1139             return self._process_response(
#    1140                 cast_to=cast_to,
#    1141                 options=prepared,
#    (...)   1145                 retries_taken=retries_taken,
#    1146             )
#
# File ~/nlp up/hw_week_1/.venv/lib/python3.13/site-packages/anthropic/_base_client.py:1275, in SyncAPIClient._attempt_request(self, options, stream, retries_taken)
#    1265 """Prepare, build and send a single HTTP attempt.
#    1266
#    1267 Returns the response regardless of its status code, along with the prepared
#    (...)   1271 `APIConnectionError`).
#    1272 """
#    1273 options = self._prepare_options(options)
# -> 1275 request = self._build_request(options, retries_taken=retries_taken)
#    1276 self._prepare_request(request)
#    1278 kwargs: HttpxSendArgs = {}
#
# File ~/nlp up/hw_week_1/.venv/lib/python3.13/site-packages/anthropic/_base_client.py:542, in BaseClient._build_request(self, options, retries_taken)
#     539     else:
#     540         raise RuntimeError(f"Unexpected JSON data type, {type(json_data)}, cannot merge with `extra_body`")
# --> 542 headers = self._build_headers(options, retries_taken=retries_taken)
#     543 params = _merge_mappings(self.default_query, options.params)
#     544 content_type = headers.get("Content-Type")
#
# File ~/nlp up/hw_week_1/.venv/lib/python3.13/site-packages/anthropic/_base_client.py:489, in BaseClient._build_headers(self, options, retries_taken)
#     473 # lowest precedence first; any of these can be overridden or `Omit`-ted by the layers after it
#     474 headers, omitted = build_headers(
#     475     {
#     476         "x-stainless-timeout": str(options.timeout.read)
#    (...)    487     options.headers or {},
#     488 )
# --> 489 self._validate_headers(headers, omitted)
#     491 return headers
#
# File ~/nlp up/hw_week_1/.venv/lib/python3.13/site-packages/anthropic/_client.py:409, in Anthropic._validate_headers(self, headers, omitted)
#     406 if headers.get("Authorization") or "authorization" in omitted:
#     407     return
# --> 409 raise TypeError(
#     410     '"Could not resolve authentication method. Expected one of api_key, auth_token, or credentials to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"'
#     411 )
#
# TypeError: "Could not resolve authentication method. Expected one of api_key, auth_token, or credentials to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"
